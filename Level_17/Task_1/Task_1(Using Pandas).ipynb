# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("ipl_over_data.csv",low_memory=False)
df
# Out:
#        year series_type                 series_name   match_no match_type  \
# 0      2021  T20 League  Indian Premier League 2021  1st Match    T20 IPL
# 1      2021  T20 League  Indian Premier League 2021  1st Match    T20 IPL
# 2      2021  T20 League  Indian Premier League 2021  1st Match    T20 IPL
# 3      2021  T20 League  Indian Premier League 2021  1st Match    T20 IPL
# 4      2021  T20 League  Indian Premier League 2021  1st Match    T20 IPL
# ...     ...         ...                         ...        ...        ...
# 22699  2020  T20 League  Indian Premier League 2020      Final    T20 IPL
# 22700  2020  T20 League  Indian Premier League 2020      Final    T20 IPL
# 22701  2020  T20 League  Indian Premier League 2020      Final    T20 IPL
# 22702  2020  T20 League  Indian Premier League 2020      Final    T20 IPL
# 22703  2020  T20 League  Indian Premier League 2020      Final    T20 IPL
#
#        match_id                                        match_venue  \
# ...

# %%
df.columns
# Out:
# Index(['year', 'series_type', 'series_name', 'match_no', 'match_type',
#        'match_id', 'match_venue', 'match_status', 'match_winning_team',
#        'match_tie_breaker', 'match_toss', 'umpires', 'match_referee',
#        'third_umpires', 'match_datetime', 'team1_name', 'team2_name',
#        'team1_score', 'team1_wickets', 'team2_score', 'team2_wickets',
#        'team1_captain', 'team1_players', 'team1_bench', 'team1_support_staff',
#        'team2_captain', 'team2_players', 'team2_bench', 'team2_support_staff',
#        'over_no', 'over_total_runs', 'over_summary', 'over_batsman1_name',
#        'over_batsman1_curr_scr', 'over_batsman1_played_balls',
#        'over_batsman2_name', 'over_batsman2_curr_scr',
#        'over_batsman2_played_balls', 'over_bowler_name',
#        'over_bowler_bowled_overs', 'over_bowler_bowled_maidens',
#        'over_bowler_bowled_runs', 'over_bowler_bowled_wickets'],
#       dtype='object')

# %%
df.head(55).match_datetime
# Out:
# 0     2021-04-09 19:30:00+05:30
# 1     2021-04-09 19:30:00+05:30
# 2     2021-04-09 19:30:00+05:30
# 3     2021-04-09 19:30:00+05:30
# 4     2021-04-09 19:30:00+05:30
# 5     2021-04-09 19:30:00+05:30
# 6     2021-04-09 19:30:00+05:30
# 7     2021-04-09 19:30:00+05:30
# 8     2021-04-09 19:30:00+05:30
# 9     2021-04-09 19:30:00+05:30
# 10    2021-04-09 19:30:00+05:30
# 11    2021-04-09 19:30:00+05:30
# 12    2021-04-09 19:30:00+05:30
# 13    2021-04-09 19:30:00+05:30
# 14    2021-04-09 19:30:00+05:30
# 15    2021-04-09 19:30:00+05:30
# 16    2021-04-09 19:30:00+05:30
# 17    2021-04-09 19:30:00+05:30
# 18    2021-04-09 19:30:00+05:30
# 19    2021-04-09 19:30:00+05:30
# 20    2021-04-09 19:30:00+05:30
# 21    2021-04-09 19:30:00+05:30
# 22    2021-04-09 19:30:00+05:30
# 23    2021-04-09 19:30:00+05:30
# 24    2021-04-09 19:30:00+05:30
# 25    2021-04-09 19:30:00+05:30
# 26    2021-04-09 19:30:00+05:30
# 27    2021-04-09 19:30:00+05:30
# 28    2021-04-09 19:30:00+05:30
# ...

# %%
df[['date','time']]=df.match_datetime.str.split(expand=True)

# %%
df.columns
# Out:
# Index(['year', 'series_type', 'series_name', 'match_no', 'match_type',
#        'match_id', 'match_venue', 'match_status', 'match_winning_team',
#        'match_tie_breaker', 'match_toss', 'umpires', 'match_referee',
#        'third_umpires', 'match_datetime', 'team1_name', 'team2_name',
#        'team1_score', 'team1_wickets', 'team2_score', 'team2_wickets',
#        'team1_captain', 'team1_players', 'team1_bench', 'team1_support_staff',
#        'team2_captain', 'team2_players', 'team2_bench', 'team2_support_staff',
#        'over_no', 'over_total_runs', 'over_summary', 'over_batsman1_name',
#        'over_batsman1_curr_scr', 'over_batsman1_played_balls',
#        'over_batsman2_name', 'over_batsman2_curr_scr',
#        'over_batsman2_played_balls', 'over_bowler_name',
#        'over_bowler_bowled_overs', 'over_bowler_bowled_maidens',
#        'over_bowler_bowled_runs', 'over_bowler_bowled_wickets', 'date',
#        'time'],
#       dtype='object')

# %%
df.date
# Out:
# 0        2021-04-09
# 1        2021-04-09
# 2        2021-04-09
# 3        2021-04-09
# 4        2021-04-09
#             ...
# 22699    2020-11-10
# 22700    2020-11-10
# 22701    2020-11-10
# 22702    2020-11-10
# 22703    2020-11-10
# Name: date, Length: 22704, dtype: object

# %%
df.time
# Out:
# 0        19:30:00+05:30
# 1        19:30:00+05:30
# 2        19:30:00+05:30
# 3        19:30:00+05:30
# 4        19:30:00+05:30
#               ...
# 22699    19:30:00+05:30
# 22700    19:30:00+05:30
# 22701    19:30:00+05:30
# 22702    19:30:00+05:30
# 22703    19:30:00+05:30
# Name: time, Length: 22704, dtype: object
